# %% [markdown]
# <a href="https://colab.research.google.com/github/sleemgeez/DataScience-Projects/blob/main/Copy_of_IS6703_HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #P1 (100pt): Write a Python code in Colab using NumPy, Panda, Scikit-Learn to complete the following tasks:

# %%
import pandas as pd
import numpy as np
np.random.seed(100)
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# 1. Import the Auto MPG dataset with pandas.read_csv() using the dataset URL, use the attribute names as explained in the dataset description as the column names **(10pt)**, view the strings ‘?’ as the missing value, and whitespace (i.e., ‘\s+’) as the column delimiter. Print out the shape and first 5 rows of the obtained DataFrame. **(10pt)**
#
# * Dataset source file:
# http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# * Dataset description: http://archive.ics.uci.edu/ml/datasets/Auto+MPG
# * To have reproducible results using Scikit-Learn in Jupyter Notebook for the training/testing, you can set the seed at the beginning of your notebook
# https://www.mikulskibartosz.name/how-to-set-the-global-random_state-in-scikit-learn/

# %%
# put your answer here
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names = ['displacement', 'mpg', 'cylinders', 'horespower', 'weight', 'acceleration', 'model_year', 'origin', 'car_name']
df = pd.read_csv(url, sep='\s+', na_values='?', names=column_names)

print(df.shape)

df.head()
# Out:
# (398, 9)
#    displacement  mpg  cylinders  horespower  weight  acceleration  model_year  \
# 0          18.0    8      307.0       130.0  3504.0          12.0          70
# 1          15.0    8      350.0       165.0  3693.0          11.5          70
# 2          18.0    8      318.0       150.0  3436.0          11.0          70
# 3          16.0    8      304.0       150.0  3433.0          12.0          70
# 4          17.0    8      302.0       140.0  3449.0          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# 2.	Delete the “car_name” column using .drop() method as it is irrelevant to the prediction. Print out a concise summary of the new DataFrame using .info() and check if NULL value exists in each column **(10pt)**

# %%
# put your answer here
df = df.drop('car_name', axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   displacement  398 non-null    float64
#  1   mpg           398 non-null    int64
#  2   cylinders     398 non-null    float64
#  3   horespower    392 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 25.0 KB

# %% [markdown]
# 3.	Replace the NULL value with the mean value of the column using .fillna(). Print out the concise summary of the new DataFrame using .info() and recheck if NULL value exists in each column **(10pt)**
#   - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html

# %%
# put your answer here
df.fillna(df.mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   displacement  398 non-null    float64
#  1   mpg           398 non-null    int64
#  2   cylinders     398 non-null    float64
#  3   horespower    398 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 25.0 KB

# %% [markdown]
# 4.	Read the following tutorial on one-hot-encoding first. Then for the ‘origin’ column with categorical attribute, replace it with the columns with numerical attributes using one-hot encoding (you can use either get_dummies() in Pandas or OneHotEncoder: in Scikit-Learn). Print out the first 5 rows of the newly obtained DataFrame. **(20pt)**
#
# 	a.	https://stackabuse.com/one-hot-encoding-in-python-with-pandas-and-scikit-learn/

# %%
# put your answer here
df_oneHot = pd.get_dummies(df, columns=['origin'])

df_oneHot.head()
# Out:
#    displacement  mpg  cylinders  horespower  weight  acceleration  model_year  \
# 0          18.0    8      307.0       130.0  3504.0          12.0          70
# 1          15.0    8      350.0       165.0  3693.0          11.5          70
# 2          18.0    8      318.0       150.0  3436.0          11.0          70
# 3          16.0    8      304.0       150.0  3433.0          12.0          70
# 4          17.0    8      302.0       140.0  3449.0          10.5          70
#
#    origin_1  origin_2  origin_3
# 0         1         0         0
# 1         1         0         0
# 2         1         0         0
# 3         1         0         0
# 4         1         0         0

# %% [markdown]
# 5.	Learn a linear regression model (fit_intercept=True) to predict the “mpg” column from the remaining columns in the obtained DataFrame of Step 4.
#
#   a.	Separate the “mpg” column from other columns and view it as the label vector and others as the feature matrix **(10pt)**
#
#   b.	Split the data into a training set (80%) and testing set (20%) using train_test_split and print out their shapes **(10pt)**
#     - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# put your answer here
x = df_oneHot.drop('mpg', axis=1)  # Feature matrix
y = df_oneHot['mpg']  # Label vector

# Viewing first few rows of the features and labels
print(x.head())
print('\n')
print(y.head())

# Spliting the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# Shapes
print("x_train's shape:", x_train.shape)
print("x_test's shape:", x_test.shape)
print("y_train's shape:", y_train.shape)
print("y_test's shape:", y_test.shape)
# Out:
#    displacement  cylinders  horespower  weight  acceleration  model_year  \
# 0          18.0      307.0       130.0  3504.0          12.0          70
# 1          15.0      350.0       165.0  3693.0          11.5          70
# 2          18.0      318.0       150.0  3436.0          11.0          70
# 3          16.0      304.0       150.0  3433.0          12.0          70
# 4          17.0      302.0       140.0  3449.0          10.5          70
#
#    origin_1  origin_2  origin_3
# 0         1         0         0
# 1         1         0         0
# 2         1         0         0
# 3         1         0         0
# 4         1         0         0
#
#
# 0    8
# 1    8
# 2    8
# 3    8
# 4    8
# Name: mpg, dtype: int64
# x_train's shape: (318, 9)
# x_test's shape: (80, 9)
# y_train's shape: (318,)
# y_test's shape: (80,)

# %% [markdown]
#   c.	Train the model using the training set and print out the coefficients of the model **(10 pt)**

# %%
# put your answer
model = LinearRegression(fit_intercept=True)

# Training
model.fit(x_train, y_train)

# Retrieve and print the coefficients of the model
coefficients = model.coef_
print("Coefficients of the model:", coefficients)

# %% [markdown]
# d.	Use the learned model to predict on the test set and print out the mean squared error of the predictions **(10pt)**

# %%
# put your answer here
